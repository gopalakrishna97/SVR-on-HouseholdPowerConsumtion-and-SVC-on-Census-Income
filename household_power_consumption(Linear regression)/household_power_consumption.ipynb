# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline  
sns.set()

# %% [markdown]
# ## Importing household_power_consumption dataset

# %%
data = pd.read_csv('household_power_consumption.txt', sep=';',parse_dates={'Date_Time' : ['Date', 'Time']},
                   infer_datetime_format=True,
                   low_memory=False)
data
# Out:
#                   Date_Time Global_active_power Global_reactive_power  \
# 0       2006-12-16 17:24:00               4.216                 0.418
# 1       2006-12-16 17:25:00               5.360                 0.436
# 2       2006-12-16 17:26:00               5.374                 0.498
# 3       2006-12-16 17:27:00               5.388                 0.502
# 4       2006-12-16 17:28:00               3.666                 0.528
# ...                     ...                 ...                   ...
# 2075254 2010-11-26 20:58:00               0.946                 0.000
# 2075255 2010-11-26 20:59:00               0.944                 0.000
# 2075256 2010-11-26 21:00:00               0.938                 0.000
# 2075257 2010-11-26 21:01:00               0.934                 0.000
# 2075258 2010-11-26 21:02:00               0.932                 0.000
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# ...

# %%
data.columns
# Out:
# Index(['Date_Time', 'Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date_Time              datetime64[ns]
#  1   Global_active_power    object
#  2   Global_reactive_power  object
#  3   Voltage                object
#  4   Global_intensity       object
#  5   Sub_metering_1         object
#  6   Sub_metering_2         object
#  7   Sub_metering_3         float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 126.7+ MB

# %%
data.isna().sum()
# Out:
# Date_Time                    0
# Global_active_power          0
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Sub_metering_1               0
# Sub_metering_2               0
# Sub_metering_3           25979
# dtype: int64

# %%
sample_data = data.sample(n=15000)
sample_data
# Out:
#                   Date_Time Global_active_power Global_reactive_power  \
# 1484249 2009-10-12 10:53:00               1.466                 0.278
# 451235  2007-10-26 01:59:00               0.506                 0.098
# 163492  2007-04-09 06:16:00               0.466                 0.354
# 248965  2007-06-07 14:49:00               0.682                 0.052
# 970130  2008-10-20 10:14:00               1.302                 0.052
# ...                     ...                 ...                   ...
# 179583  2007-04-20 10:27:00               0.294                 0.228
# 1332567 2009-06-29 02:51:00               0.458                 0.116
# 450232  2007-10-25 09:16:00               1.876                 0.000
# 3282    2006-12-19 00:06:00               0.390                 0.218
# 596728  2008-02-04 02:52:00               0.298                 0.092
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# ...

# %%
sample_data.isna().sum()
# Out:
# Date_Time                  0
# Global_active_power        0
# Global_reactive_power      0
# Voltage                    0
# Global_intensity           0
# Sub_metering_1             0
# Sub_metering_2             0
# Sub_metering_3           186
# dtype: int64

# %%
sample_data.dropna(inplace=True)

# %%
sample_data.isna().sum()
# Out:
# Date_Time                0
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
sample_data.shape
# Out:
# (14814, 8)

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14814 entries, 1484249 to 596728
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date_Time              14814 non-null  datetime64[ns]
#  1   Global_active_power    14814 non-null  object
#  2   Global_reactive_power  14814 non-null  object
#  3   Voltage                14814 non-null  object
#  4   Global_intensity       14814 non-null  object
#  5   Sub_metering_1         14814 non-null  object
#  6   Sub_metering_2         14814 non-null  object
#  7   Sub_metering_3         14814 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 1.0+ MB

# %%
for column in sample_data.iloc[:,1:].columns:
    if sample_data[column].dtype == 'O':
        sample_data[column]=pd.to_numeric(data[column], errors='coerce')

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14814 entries, 1484249 to 596728
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date_Time              14814 non-null  datetime64[ns]
#  1   Global_active_power    14814 non-null  float64
#  2   Global_reactive_power  14814 non-null  float64
#  3   Voltage                14814 non-null  float64
#  4   Global_intensity       14814 non-null  float64
#  5   Sub_metering_1         14814 non-null  float64
#  6   Sub_metering_2         14814 non-null  float64
#  7   Sub_metering_3         14814 non-null  float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 1.0 MB

# %% [markdown]
# ### Finding total energy from three sub meters by adding all three

# %%
sample_data["total_energy"] = sample_data['Sub_metering_1']+sample_data['Sub_metering_2']+sample_data['Sub_metering_3']

# %%
sample_data.head()
# Out:
#                   Date_Time  Global_active_power  Global_reactive_power  \
# 1484249 2009-10-12 10:53:00                1.466                  0.278
# 451235  2007-10-26 01:59:00                0.506                  0.098
# 163492  2007-04-09 06:16:00                0.466                  0.354
# 248965  2007-06-07 14:49:00                0.682                  0.052
# 970130  2008-10-20 10:14:00                1.302                  0.052
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 1484249   235.69               6.2             0.0             1.0
# 451235    243.47               2.4             0.0             0.0
# 163492    242.31               2.4             0.0             2.0
# 248965    236.95               2.8             0.0             0.0
# 970130    240.01               5.4             0.0             0.0
#
#          Sub_metering_3  total_energy
# 1484249            18.0          19.0
# 451235              0.0           0.0
# ...

# %%
sample_data.drop(['Sub_metering_1', 'Sub_metering_2','Sub_metering_3'], axis=1,inplace=True)

# %%
sample_data
# Out:
#                   Date_Time  Global_active_power  Global_reactive_power  \
# 1484249 2009-10-12 10:53:00                1.466                  0.278
# 451235  2007-10-26 01:59:00                0.506                  0.098
# 163492  2007-04-09 06:16:00                0.466                  0.354
# 248965  2007-06-07 14:49:00                0.682                  0.052
# 970130  2008-10-20 10:14:00                1.302                  0.052
# ...                     ...                  ...                    ...
# 179583  2007-04-20 10:27:00                0.294                  0.228
# 1332567 2009-06-29 02:51:00                0.458                  0.116
# 450232  2007-10-25 09:16:00                1.876                  0.000
# 3282    2006-12-19 00:06:00                0.390                  0.218
# 596728  2008-02-04 02:52:00                0.298                  0.092
#
#          Voltage  Global_intensity  total_energy
# 1484249   235.69               6.2          19.0
# ...

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in sample_data.columns: ## excluding first two columns which contains date and time 
    if plotnumber<=6:
        ax = plt.subplot(2,3,plotnumber)
        sns.distplot(sample_data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sample_data.columns
# Out:
# Index(['Date_Time', 'Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'total_energy'],
#       dtype='object')

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in sample_data.iloc[:,1:].columns: ## excluding first column which contains date and time 
    if plotnumber<=5:
        ax = plt.subplot(2,3,plotnumber)
        sns.boxplot(sample_data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.pairplot(sample_data)

# %%
sample_data.corr()
# Out:
#                        Global_active_power  Global_reactive_power   Voltage  \
# Global_active_power               1.000000               0.238290 -0.392173
# Global_reactive_power             0.238290               1.000000 -0.097538
# Voltage                          -0.392173              -0.097538  1.000000
# Global_intensity                  0.998840               0.257710 -0.403613
# total_energy                      0.842284               0.173438 -0.343204
#
#                        Global_intensity  total_energy
# Global_active_power            0.998840      0.842284
# Global_reactive_power          0.257710      0.173438
# Voltage                       -0.403613     -0.343204
# Global_intensity               1.000000      0.839120
# total_energy                   0.839120      1.000000

# %% [markdown]
# ### Global_intensity and Global_active_power are 99% correlated. we can drop any one feature, but i am keeping as it is

# %% [markdown]
# # connecting the mongoDB

# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://gopalakrishna97:Gopal123@krishna.wdftn.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
print(db)
# Out:
# Database(MongoClient(host=['krishna-shard-00-01.wdftn.mongodb.net:27017', 'krishna-shard-00-00.wdftn.mongodb.net:27017', 'krishna-shard-00-02.wdftn.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-v4pjmo-shard-0', tls=True), 'test')

# %%
dbname = client['MachineLearning']
collection = dbname['power_consumption']

# %%
for i in client.list_databases():
    print(i)
# Out:
# {'name': 'inventory', 'sizeOnDisk': 57344, 'empty': False}
# {'name': 'mongotest', 'sizeOnDisk': 73728, 'empty': False}
# {'name': 'my_data', 'sizeOnDisk': 73728, 'empty': False}
# {'name': 'youtubeScraper', 'sizeOnDisk': 18563072, 'empty': False}
# {'name': 'admin', 'sizeOnDisk': 344064, 'empty': False}
# {'name': 'local', 'sizeOnDisk': 2890485760, 'empty': False}

# %%
data = sample_data.to_dict(orient='records')

# %%
data
# Out:
# [{'Date_Time': Timestamp('2009-10-12 10:53:00'),
#   'Global_active_power': 1.466,
#   'Global_reactive_power': 0.278,
#   'Voltage': 235.69,
#   'Global_intensity': 6.2,
#   'total_energy': 19.0},
#  {'Date_Time': Timestamp('2007-10-26 01:59:00'),
#   'Global_active_power': 0.506,
#   'Global_reactive_power': 0.098,
#   'Voltage': 243.47,
#   'Global_intensity': 2.4,
#   'total_energy': 0.0},
#  {'Date_Time': Timestamp('2007-04-09 06:16:00'),
#   'Global_active_power': 0.466,
#   'Global_reactive_power': 0.354,
#   'Voltage': 242.31,
#   'Global_intensity': 2.4,
#   'total_energy': 2.0},
#  {'Date_Time': Timestamp('2007-06-07 14:49:00'),
#   'Global_active_power': 0.682,
#   'Global_reactive_power': 0.052,
#   'Voltage': 236.95,
#   'Global_intensity': 2.8,
#   'total_energy': 0.0},
#  {'Date_Time': Timestamp('2008-10-20 10:14:00'),
#   'Global_active_power': 1.302,
#   'Global_reactive_power': 0.052,
#   'Voltage': 240.01,
#   'Global_intensity': 5.4,
#   'total_energy': 19.0},
# ...

# %%
collection.insert_many(data)

# %%
get_data = collection.find()

# %%
for i in get_data:
    print(i)
# Out:
# {'_id': ObjectId('636244ea8597c6037c07db9a'), 'Date_Time': datetime.datetime(2009, 10, 12, 10, 53), 'Global_active_power': 1.466, 'Global_reactive_power': 0.278, 'Voltage': 235.69, 'Global_intensity': 6.2, 'total_energy': 19.0}
# {'_id': ObjectId('636244ea8597c6037c07db9b'), 'Date_Time': datetime.datetime(2007, 10, 26, 1, 59), 'Global_active_power': 0.506, 'Global_reactive_power': 0.098, 'Voltage': 243.47, 'Global_intensity': 2.4, 'total_energy': 0.0}
# {'_id': ObjectId('636244ea8597c6037c07db9c'), 'Date_Time': datetime.datetime(2007, 4, 9, 6, 16), 'Global_active_power': 0.466, 'Global_reactive_power': 0.354, 'Voltage': 242.31, 'Global_intensity': 2.4, 'total_energy': 2.0}
# {'_id': ObjectId('636244ea8597c6037c07db9d'), 'Date_Time': datetime.datetime(2007, 6, 7, 14, 49), 'Global_active_power': 0.682, 'Global_reactive_power': 0.052, 'Voltage': 236.95, 'Global_intensity': 2.8, 'total_energy': 0.0}
# ...

# %%
mongo_data = pd.DataFrame(list(collection.find()))

# %%
mongo_data
# Out:
#                             _id           Date_Time  Global_active_power  \
# 0      636244ea8597c6037c07db9a 2009-10-12 10:53:00                1.466
# 1      636244ea8597c6037c07db9b 2007-10-26 01:59:00                0.506
# 2      636244ea8597c6037c07db9c 2007-04-09 06:16:00                0.466
# 3      636244ea8597c6037c07db9d 2007-06-07 14:49:00                0.682
# 4      636244ea8597c6037c07db9e 2008-10-20 10:14:00                1.302
# ...                         ...                 ...                  ...
# 14809  636244ea8597c6037c081573 2007-04-20 10:27:00                0.294
# 14810  636244ea8597c6037c081574 2009-06-29 02:51:00                0.458
# 14811  636244ea8597c6037c081575 2007-10-25 09:16:00                1.876
# 14812  636244ea8597c6037c081576 2006-12-19 00:06:00                0.390
# 14813  636244ea8597c6037c081577 2008-02-04 02:52:00                0.298
#
#        Global_reactive_power  Voltage  Global_intensity  total_energy
# ...

# %%
mongo_data.columns
# Out:
# Index(['_id', 'Date_Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'total_energy'],
#       dtype='object')

# %%
mongo_data.drop('_id', axis=1 ,inplace=True)

# %%
mongo_data['Date_Time'] = pd.to_numeric(mongo_data['Date_Time'], errors='coerce')

# %%
mongo_data.head()
# Out:
#              Date_Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  1255344780000000000                1.466                  0.278   235.69
# 1  1193363940000000000                0.506                  0.098   243.47
# 2  1176099360000000000                0.466                  0.354   242.31
# 3  1181227740000000000                0.682                  0.052   236.95
# 4  1224497640000000000                1.302                  0.052   240.01
#
#    Global_intensity  total_energy
# 0               6.2          19.0
# 1               2.4           0.0
# 2               2.4           2.0
# 3               2.8           0.0
# 4               5.4          19.0

# %% [markdown]
# # Separating Independent and Dependent Columns

# %%
X = mongo_data.iloc[:,:-1] # taking all the features in to X variable except the last feature that is total_energy
y = mongo_data.iloc[:,-1] # taking all the data point of the total_energy column

# %%
X.head()
# Out:
#              Date_Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  1255344780000000000                1.466                  0.278   235.69
# 1  1193363940000000000                0.506                  0.098   243.47
# 2  1176099360000000000                0.466                  0.354   242.31
# 3  1181227740000000000                0.682                  0.052   236.95
# 4  1224497640000000000                1.302                  0.052   240.01
#
#    Global_intensity
# 0               6.2
# 1               2.4
# 2               2.4
# 3               2.8
# 4               5.4

# %%
y
# Out:
# 0        19.0
# 1         0.0
# 2         2.0
# 3         0.0
# 4        19.0
#          ...
# 14809     0.0
# 14810     2.0
# 14811    18.0
# 14812     1.0
# 14813     1.0
# Name: total_energy, Length: 14814, dtype: float64

# %% [markdown]
# # Splitting training and testing data by Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#                  Date_Time  Global_active_power  Global_reactive_power  \
# 4325   1246898280000000000                0.236                  0.128
# 3219   1251481020000000000                0.340                  0.240
# 12703  1275943500000000000                0.938                  0.000
# 6740   1238334300000000000                1.548                  0.000
# 1193   1224018420000000000                1.870                  0.000
# ...                    ...                  ...                    ...
# 5191   1272559740000000000                0.244                  0.000
# 13418  1196898120000000000                0.404                  0.000
# 5390   1211469840000000000                0.528                  0.242
# 860    1172149440000000000                0.342                  0.114
# 7270   1174211160000000000                2.686                  0.152
#
#        Voltage  Global_intensity
# 4325    240.62               1.0
# 3219    242.70               1.6
# ...

# %%
y_train
# Out:
# 4325      1.0
# 3219      2.0
# 12703     1.0
# 6740     18.0
# 1193      1.0
#          ...
# 5191      0.0
# 13418     0.0
# 5390      2.0
# 860       1.0
# 7270     39.0
# Name: total_energy, Length: 10369, dtype: float64

# %%
X_test
# Out:
#                  Date_Time  Global_active_power  Global_reactive_power  \
# 11147  1261013160000000000                0.246                  0.000
# 3105   1198142700000000000                1.258                  0.058
# 13325  1178071140000000000                0.466                  0.186
# 2177   1273344960000000000                0.302                  0.000
# 8176   1238232420000000000                1.500                  0.102
# ...                    ...                  ...                    ...
# 5963   1220673900000000000                1.342                  0.188
# 13043  1288984200000000000                1.504                  0.000
# 8331   1255740300000000000                0.296                  0.060
# 8589   1174145400000000000                1.442                  0.188
# 12694  1243955400000000000                0.212                  0.000
#
#        Voltage  Global_intensity
# 11147   248.67               1.0
# 3105    238.07               5.2
# ...

# %%
y_test
# Out:
# 11147     1.0
# 3105     18.0
# 13325     1.0
# 2177      3.0
# 8176     19.0
#          ...
# 5963     19.0
# 13043     1.0
# 8331      1.0
# 8589     17.0
# 12694     1.0
# Name: total_energy, Length: 4445, dtype: float64

# %% [markdown]
# # Standardizing dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.53359384, -0.8110502 ,  0.02791674, -0.07243345, -0.81840247],
#        [ 0.66075794, -0.71252154,  1.0102963 ,  0.56791622, -0.68323323],
#        [ 1.33955471, -0.14598172, -1.09480276, -0.17710599, -0.18761267],
#        ...,
#        [-0.44949172, -0.53441203,  1.02783879, -0.60811058, -0.45795115],
#        [-1.54057327, -0.71062676, -0.09488071,  0.31854928, -0.72828964],
#        [-1.48336366,  1.51005774,  0.23842664,  0.4078288 ,  1.47947466]])

# %%
X_test
# Out:
# array([[ 0.92526039, -0.80157629, -1.09480276,  2.40584293, -0.81840247],
#        [-0.81929967,  0.1571834 , -0.58607049, -0.85747752,  0.12778223],
#        [-1.37625506, -0.59315027,  0.53664901, -1.48243417, -0.54806398],
#        ...,
#        [ 0.77894651, -0.75420674, -0.56852799,  0.67566737, -0.77334605],
#        [-1.4851884 ,  0.33150334,  0.5541915 , -1.30695373,  0.30800789],
#        [ 0.45193338, -0.83378759, -1.09480276,  0.98352779, -0.81840247]])

# %%
# pickling the scaler object in to scaling.pkl file
import pickle
pickle.dump(scaler,open('Standard_scaling.pkl','wb'))

# %% [markdown]
# <h1><center>Linear regression</center></h1>

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the co-efficients
print(regression.coef_)
# Out:
# [  0.7808589   22.35782435  -0.12185255  -0.6680636  -11.78283304]

# %%
print(regression.intercept_)
# Out:
# 8.845211688687437

# %%
## on which parameters the model has been trained
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
## prediction with the test data
reg_pred = regression.predict(X_test)

# %%
print(reg_pred)
# Out:
# [-0.18454435 10.85835996  1.89171572 ...  1.3211324  12.27357552
#  -0.32412345]

# %%
from sklearn.metrics  import mean_squared_error
from sklearn.metrics  import mean_absolute_error

# %%
print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 4.308895811339149
# 45.29836692186121
# 6.7304061483584485

# %% [markdown]
# ## R^2 Score

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,reg_pred)
score
# Out:
# 0.704651176185817

# %% [markdown]
# ## Adjusted R^2 Score

# %%
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.7043185012322078

# %% [markdown]
# <h1><center> Ridge Regression </center></h1>

# %%
## Ridge
from sklearn.linear_model import Ridge
ridge=Ridge()

# %%
ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
redge_pred = ridge.predict(X_test)
print('Redge predicted values',redge_pred)
# Out:
# Redge predicted values [-0.13031248 10.80865606  1.89989067 ...  1.31364572 12.18403239
#  -0.24988763]

# %%
print('MSE',mean_squared_error(y_test,redge_pred))
print('MAE',mean_absolute_error(y_test,redge_pred))
print('RMSE',np.sqrt(mean_squared_error(y_test,redge_pred)))
# Out:
# MSE 45.312103836484
# MAE 4.310211023284747
# RMSE 6.731426582566581

# %%
# performance metrics
# R^2 
redge_score=r2_score(y_test,redge_pred)
print('R^2',score)

# adjusted R^2

print("Adjusted R^2",1 - (1-redge_score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# R^2 0.704651176185817
# Adjusted R^2 0.7042288346110883

# %% [markdown]
# <h1><center> Lasso Regression </center></h1>

# %%
# lasso
from sklearn.linear_model import Lasso
lasso = Lasso()

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso()

# %%
lasso_pred = ridge.predict(X_test)
print('Lasso predicted values',lasso_pred)
# Out:
# Lasso predicted values [-0.13031248 10.80865606  1.89989067 ...  1.31364572 12.18403239
#  -0.24988763]

# %%
print('MSE',mean_squared_error(y_test,lasso_pred))
print('MAE',mean_absolute_error(y_test,lasso_pred))
print('RMSE',np.sqrt(mean_squared_error(y_test,lasso_pred)))
# Out:
# MSE 45.312103836484
# MAE 4.310211023284747
# RMSE 6.731426582566581

# %%
# performance metrics
# R^2 
lasso_score=r2_score(y_test,lasso_pred)
print('R^2',score)

# adjusted R^2

print('Adjusted R^2',1 - (1-lasso_score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# R^2 0.704651176185817
# Adjusted R^2 0.7042288346110883

# %% [markdown]
# <h1><center>ElasticNet Regression</center></h1>

# %%
# ElasticNet
from sklearn.linear_model import ElasticNet
ElasticNet = ElasticNet()

# %%
ElasticNet.fit(X_train,y_train)
# Out:
# ElasticNet()

# %%
ElasticNet_pred = ridge.predict(X_test)
print('ElasticNet predicted values',ElasticNet_pred)
# Out:
# ElasticNet predicted values [-0.13031248 10.80865606  1.89989067 ...  1.31364572 12.18403239
#  -0.24988763]

# %%
print('MSE',mean_squared_error(y_test,ElasticNet_pred))
print('MAE',mean_absolute_error(y_test,ElasticNet_pred))
print('RMSE',np.sqrt(mean_squared_error(y_test,ElasticNet_pred)))
# Out:
# MSE 45.312103836484
# MAE 4.310211023284747
# RMSE 6.731426582566581

# %%
# performance metrics
# R^2 
ElasticNet_score=r2_score(y_test,ElasticNet_pred)
print('R^2',score)

# adjusted R^2

print('Adjusted R^2',1 - (1-ElasticNet_score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# R^2 0.704651176185817
# Adjusted R^2 0.7042288346110883

# %% [markdown]
# <h1><center>Support Vector Regression - SVR</center></h1>

# %%
from sklearn.svm import SVR
SVR_model=SVR(kernel='rbf')

# %%
SVR_model.fit(X_train,y_train)
# Out:
# SVR()

# %%
y_predict=SVR_model.predict(X_test)

# %%
y_predict
# Out:
# array([ 0.43374228, 15.47717217,  2.02616354, ...,  0.68445755,
#        16.71767218,  0.46144132])

# %%
from sklearn.metrics import r2_score
svr_score=r2_score(y_test,y_predict)
print(svr_score)
# Out:
# 0.6819189211719643

# %%
print('Adjusted R^2',1 - (1-svr_score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# Adjusted R^2 0.6815606410651519
